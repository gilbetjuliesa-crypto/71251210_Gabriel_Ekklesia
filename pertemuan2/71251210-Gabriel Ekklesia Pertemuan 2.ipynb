# %%
#latihan 2.1

#mengambil input
tinggi_m = float(input("masukan tinggi badan (meter): "))
target_bmi = float(input("masukan nilai bmi: "))

#perhitungan 
berat_yang_diperlukan = target_bmi * (tinggi_m ** 2)

# hasil 
print("-" * 35)
print(f"mencari BMI {target_bmi},")
print(F"berat badan yang diperlukan adalah: {berat_yang_diperlukan:.2f} kg")
# Out:
# masukan tinggi badan (meter):  171
# masukan nilai bmi:  105
# -----------------------------------
# mencari BMI 105.0,
# berat badan yang diperlukan adalah: 3070305.00 kg

# %%
#latihan 2.2

#mengambil input 
x = int(input("masukan nilai x (bilangan bulat): "))

#perhitungan
if x !=0:
    hasil = (2 * (x ** 3)) + (2*x) + (15 / x)

#hasil
    print(f"hasil dari f({x}) adalah {hasil}")
else:
    print("eror: nilai x tidak boleh 0 karena akan terjadi pembagian dari nol")
# Out:
# masukan nilai x (bilangan bulat):  100
# hasil dari f(100) adalah 2000200.15

# %%
#latihan 2.3

#mengambil input 
gaji_per_jam = float(input("masukan gaji per jam yang diinginkan: "))
jam_kerja_minggu = float(input("masukan jam kerja per minggu: "))

#perhitungan 
pendapatan_bruto = gaji_per_jam * jam_kerja_minggu * 5

#pendapatan netto 
pajak = 0.14 * pendapatan_bruto
pendapatan_bersih = pendapatan_bruto - pajak

#belanja baju dan aksesoris (10% dari pendapatan bersih)
uang_baju = 0.01 * pendapatan_bersih

#belanja alat tulis (1% dari pendapatan bersih)
uang_belanja_alat_tulis = 0.01 * pendapatan_bersih

#sedekah (25% dari sisa uang belanja)
sisa_uang_belanja = pendapatan_bersih - uang_baju - uang_belanja_alat_tulis 
total_sedekah = 0.25 * sisa_uang_belanja 

#pembagian sedekah 
uang_anak_yatim = 0.30 * total_sedekah
uang_kaum_dhuafa = total_sedekah - uang_anak_yatim

print("\n" + "="*40)
print(f" pendapatan bruto budi : Rp {pendapatan_bruto:,.2f}")
print(f" pendapatan netto setelah pajak : Rp {pendapatan_bersih:,.2f}")
print(f" uang untuk belanja untuk membeli pakaian : Rp {uang_baju:,.2f}")
print(f" uang untuk membeli alat tulis : Rp {uang_belanja_alat_tulis:,.2f}")
print(f" total uang yang disedekahkan : RP {total_sedekah:,.2f}")
print(f" total sedekah untuk anak yatim : Rp {uang_anak_yatim:,.2f}")
print(f" uang sedekah untuk kaum dhufan : Rp {uang_kaum_dhuafa:,.2f}")
print("="*40)
# Out:
# masukan gaji per jam yang diinginkan:  10000000000
# masukan jam kerja per minggu:  10
# ========================================
#  pendapatan bruto budi : Rp 500,000,000,000.00
#  pendapatan netto setelah pajak : Rp 430,000,000,000.00
#  uang untuk belanja untuk membeli pakaian : Rp 4,300,000,000.00
#  uang untuk membeli alat tulis : Rp 4,300,000,000.00
#  total uang yang disedekahkan : RP 105,350,000,000.00
#  total sedekah untuk anak yatim : Rp 31,605,000,000.00
#  uang sedekah untuk kaum dhufan : Rp 73,745,000,000.00
# ========================================
